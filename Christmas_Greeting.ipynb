# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Create a festive background
x = np.linspace(0, 10, 500)
y = np.sin(x) * 0.5 + 3  # A wavy pattern
ax.fill_between(x, y, color="lightgreen", alpha=0.3)

# Add a Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [2, 5, 2]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(plt.Rectangle((4.8, 1.5), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red and gold circles)
ornament_positions = [(4.75, 3.5), (5.25, 4.2), (4.9, 2.8), (5.1, 3.1)]
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color="red", zorder=10))

# Add the star on top of the tree
ax.scatter(5, 5, color="gold", s=200, marker="*")

# Add festive text
ax.text(5, 5.5, "Merry Christmas", color="darkred", fontsize=24, ha='center', fontweight='bold')
ax.text(5, 5.3, "and", color="darkred", fontsize=18, ha='center')
ax.text(5, 5.1, "Happy New Year 2025!", color="darkblue", fontsize=22, ha='center', fontweight='bold')

# Add decorative snowflakes
for _ in range(50):
    x_snow = np.random.uniform(0, 10)
    y_snow = np.random.uniform(0, 6)
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(10, 50), alpha=0.8)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [2, 5, 2]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(plt.Rectangle((4.8, 1.5), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red and gold circles)
ornament_positions = [(4.75, 3.5), (5.25, 4.2), (4.9, 2.8), (5.1, 3.1)]
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color="red", zorder=10))

# Add the star on top of the tree
ax.scatter(5, 5, color="gold", s=200, marker="*")

# Add festive text
ax.text(5, 5.5, "Merry Christmas", color="white", fontsize=24, ha='center', fontweight='bold')
ax.text(5, 5.3, "and", color="white", fontsize=18, ha='center')
ax.text(5, 5.1, "Happy New Year 2025!", color="white", fontsize=22, ha='center', fontweight='bold')

# Add decorative snowflakes
for _ in range(50):
    x_snow = np.random.uniform(0, 10)
    y_snow = np.random.uniform(0, 6)
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(10, 50), alpha=0.8)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [2, 5, 2]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(plt.Rectangle((4.8, 1.5), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red and gold circles)
ornament_positions = [(4.75, 3.5), (5.25, 4.2), (4.9, 2.8), (5.1, 3.1)]
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color="red", zorder=10))

# Add the star on top of the tree
ax.scatter(5, 5, color="gold", s=200, marker="*")

# Add festive text with more spacing
ax.text(5, 5.7, "Merry Christmas", color="white", fontsize=26, ha='center', fontweight='bold')
ax.text(5, 5.4, "and", color="white", fontsize=20, ha='center')
ax.text(5, 5.1, "Happy New Year 2025!", color="white", fontsize=24, ha='center', fontweight='bold')

# Add decorative snowflakes
for _ in range(50):
    x_snow = np.random.uniform(0, 10)
    y_snow = np.random.uniform(0, 6)
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(10, 50), alpha=0.8)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes

# Set the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add tree trunk
ax.add_patch(plt.Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4), 
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2), 
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color=np.random.choice(colors), zorder=10))

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text with contrasting color
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates
        
        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break
        
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree 
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    # Draw the main box
    ax.add_patch(plt.Rectangle((px, py), pw, ph, color=color, zorder=5))
    # Add a ribbon
    ax.add_patch(plt.Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(plt.Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse, Circle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(plt.Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4), 
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2), 
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color=np.random.choice(colors), zorder=10))

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text with contrasting color
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates
        
        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break
        
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree with fixed colors
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    # Draw the main box
    ax.add_patch(plt.Rectangle((px, py), pw, ph, color=color, zorder=5))
    # Add a ribbon
    ax.add_patch(plt.Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(plt.Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add a plush-like blue penguin with a smaller lower body
# Smaller body
ax.add_patch(Ellipse((7, 1.1), 1, 0.6, color='blue', zorder=8))  # Main body
ax.add_patch(Ellipse((7, 1.2), 0.6, 0.4, color='white', zorder=9))  # Belly

# Head
ax.add_patch(Ellipse((7, 1.5), 0.6, 0.4, color='blue', zorder=10))  # Head
ax.add_patch(Circle((6.85, 1.55), 0.05, color='white', zorder=11))  # Left eye
ax.add_patch(Circle((7.15, 1.55), 0.05, color='white', zorder=11))  # Right eye
ax.add_patch(Circle((6.85, 1.55), 0.02, color='black', zorder=12))  # Left pupil
ax.add_patch(Circle((7.15, 1.55), 0.02, color='black', zorder=12))  # Right pupil

# Beak
ax.add_patch(Ellipse((7, 1.45), 0.2, 0.08, color='orange', zorder=12))

# Feet
ax.add_patch(Ellipse((6.8, 0.8), 0.2, 0.1, color='orange', zorder=7))
ax.add_patch(Ellipse((7.2, 0.8), 0.2, 0.1, color='orange', zorder=7))

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Circle, Arc

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add the squishy penguin based on your image
# Body (round and squished)
ax.add_patch(Ellipse((5, 2), 2.5, 2.0, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((5, 2), 2.0, 1.6, color='white', zorder=9))  # White belly

# Eyes (black moon-shaped, curved closed eyes)
ax.add_patch(Arc((4.5, 2.4), 0.5, 0.4, angle=0, theta1=0, theta2=180, color='black', linewidth=3))  # Left eye curve
ax.add_patch(Arc((5.5, 2.4), 0.5, 0.4, angle=0, theta1=0, theta2=180, color='black', linewidth=3))  # Right eye curve

# Add black eyes
ax.add_patch(Circle((4.5, 2.3), 0.1, color='black', zorder=10))  # Left black eye
ax.add_patch(Circle((5.5, 2.3), 0.1, color='black', zorder=10))  # Right black eye

# Beak (small yellow oval)
ax.add_patch(Ellipse((5, 2.1), 0.2, 0.1, color='gold', zorder=10))  # Small yellow beak

# Feet (yellow and positioned low)
ax.add_patch(Ellipse((4.4, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Left foot
ax.add_patch(Ellipse((5.6, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Right foot

# Add festive text with contrasting color
ax.text(5, 5.5, "Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Background snowflakes
for _ in range(50):
    x = np.random.uniform(0, 10)
    y = np.random.uniform(0, 6)
    ax.scatter(x, y, color='white', s=np.random.uniform(20, 80), alpha=0.8)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add the squishy penguin based on your image
# Body (round and squished)
ax.add_patch(Ellipse((5, 2), 2.5, 2.0, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((5, 2), 2.0, 1.6, color='white', zorder=9))  # White belly

# Eyes (lower, smaller, thinner crescent moon-shaped eyes)
# Position adjusted to be slightly lower
ax.add_patch(Wedge((4.5, 2.3), 0.2, 0, 180, width=0.05, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((5.5, 2.3), 0.2, 0, 180, width=0.05, color='black', zorder=10))  # Right crescent eye

# Beak (small yellow oval)
ax.add_patch(Ellipse((5, 2.05), 0.2, 0.1, color='gold', zorder=11))  # Small yellow beak

# Feet (yellow and positioned low)
ax.add_patch(Ellipse((4.4, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Left foot
ax.add_patch(Ellipse((5.6, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Right foot

# Add festive text with contrasting color
ax.text(5, 5.5, "Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Background snowflakes
for _ in range(50):
    x = np.random.uniform(0, 10)
    y = np.random.uniform(0, 6)
    ax.scatter(x, y, color='white', s=np.random.uniform(20, 80), alpha=0.8)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse, Circle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(plt.Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4), 
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2), 
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(plt.Circle((ox, oy), 0.1, color=np.random.choice(colors), zorder=10))

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text with contrasting color
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates
        
        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break
        
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree with fixed colors
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    # Draw the main box
    ax.add_patch(plt.Rectangle((px, py), pw, ph, color=color, zorder=5))
    # Add a ribbon
    ax.add_patch(plt.Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(plt.Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))


# Add the squishy penguin based on your image
# Body (round and squished)
ax.add_patch(Ellipse((5, 2), 2.5, 2.0, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((5, 2), 2.0, 1.6, color='white', zorder=9))  # White belly

# Eyes (lower, smaller, thinner crescent moon-shaped eyes)
# Position adjusted to be slightly lower
ax.add_patch(Wedge((4.5, 2.3), 0.2, 0, 180, width=0.05, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((5.5, 2.3), 0.2, 0, 180, width=0.05, color='black', zorder=10))  # Right crescent eye

# Beak (small yellow oval)
ax.add_patch(Ellipse((5, 2.05), 0.2, 0.1, color='gold', zorder=11))  # Small yellow beak

# Feet (yellow and positioned low)
ax.add_patch(Ellipse((4.4, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Left foot
ax.add_patch(Ellipse((5.6, 1.2), 0.4, 0.2, color='gold', zorder=7))  # Right foot

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.1, 0.1, color=np.random.choice(colors), zorder=10))

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text with contrasting color
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree with fixed colors
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add the smaller penguin slightly to the right of its previous position
# Body (smaller and squished)
ax.add_patch(Ellipse((7.0, 1.3), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.3), 1.2, 0.9, color='white', zorder=9))  # White belly

# Eyes (lower, smaller, thinner crescent moon-shaped eyes)
ax.add_patch(Wedge((6.7, 1.5), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.5), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Beak (small yellow oval)
ax.add_patch(Ellipse((7.0, 1.4), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Feet (yellow, smaller, and positioned low for visibility)
ax.add_patch(Ellipse((6.8, 1), 0.3, 0.15, color='gold', zorder=7))  # Left foot
ax.add_patch(Ellipse((7.2, 1), 0.3, 0.15, color='gold', zorder=7))  # Right foot

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.1, 0.1, color=np.random.choice(colors), zorder=10))

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text with contrasting color
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree with fixed colors
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add the smaller penguin slightly to the right of the presents
# Body (smaller and slightly raised)
ax.add_patch(Ellipse((7.0, 1.5), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.5), 1.2, 0.9, color='white', zorder=9))  # White belly

# Eyes (lower, smaller, thinner crescent moon-shaped eyes)
ax.add_patch(Wedge((6.7, 1.7), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.7), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Beak (small yellow oval)
ax.add_patch(Ellipse((7.0, 1.6), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Feet (yellow, smaller, and moved downward for visibility)
ax.add_patch(Ellipse((6.8, 1.2), 0.3, 0.15, color='gold', zorder=7))  # Left foot
ax.add_patch(Ellipse((7.2, 1.2), 0.3, 0.15, color='gold', zorder=7))  # Right foot

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add the tree ornaments (red, gold, and light blue circles)
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']  # Set Ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))  # Larger ornaments

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text 
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add Xinni's plush penguin body
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly

# Add Xinni's plush penguin's Eyes 
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Add Xinni's plush penguin's Beak 
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Add Xinni's plush penguin's Feet 
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right foot

# Display the card
plt.show()

# %%
# This is the one!

import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add the tree ornaments (including more at the lower part)
ornament_positions = [
    # Original upper ornaments
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9),
    (4.6, 2.4), (5.4, 2.4), (4.7, 2.1), (5.3, 2.1),
    (4.9, 1.9), (5.1, 1.9), (4.75, 2.0), (5.25, 2.0)
]
colors = ['red', 'gold', 'lightblue']  # Set ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))  # Larger ornaments

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add festive text 
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative star-shaped snowflakes
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)

# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add Xinni's plush penguin body
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly

# Add Xinni's plush penguin's Eyes 
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Add Xinni's plush penguin's Beak 
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Add Xinni's plush penguin's Feet 
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right foot

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green", zorder=5)

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown", zorder=4))

# Add ornaments to the tree
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9)
]
colors = ['red', 'gold', 'lightblue']
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))

# Add a star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']
for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))

# Add Xinni's plush penguin
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left Eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right Eye
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Beak
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left Foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right Foot

# Add festive text
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative snowflakes
for _ in range(70):
    x_snow = np.random.uniform(0, 10)
    y_snow = np.random.uniform(0, 6)
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(20, 50), alpha=0.8, zorder=3)

# Display the card
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle, Polygon

# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree, centered
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green", zorder=5)

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown", zorder=4))

# Add snow accumulation on the tree
tree_snow_positions = [
    [(4.6, 3.9), (5.4, 3.9), (5, 4.1)],  # Top layer of snow
    [(4.5, 3.2), (5.5, 3.2), (5, 3.4)],  # Middle layer of snow
    [(4.4, 2.5), (5.6, 2.5), (5, 2.7)]   # Lower layer of snow
]
for snow in tree_snow_positions:
    ax.add_patch(Polygon(snow, closed=True, color="white", zorder=6))

# Add ornaments to the tree
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2)
]
colors = ['red', 'gold', 'lightblue']
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))

# Add a star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")

# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']
for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))  # Ribbon
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))  # Ribbon

# Add snow pile at the bottom
snow_x = np.linspace(0, 10, 50)
snow_y = np.sin(snow_x) * 0.2 + 0.3
ax.fill_between(snow_x, 0, snow_y, color='white', zorder=2)


# Add Xinni's plush penguin
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left Eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right Eye
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Beak
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left Foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right Foot

# Add festive text
ax.text(5, 5.5, "Xinni, Merry Christmas", color="#FFD700", fontsize=28, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')

# Add evenly spread decorative snowflakes
for _ in range(70):
    x_snow = np.random.uniform(0, 10)
    y_snow = np.random.uniform(0, 6)
    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(20, 50), alpha=0.8, zorder=3)

# Display the card
plt.show()

# %%
# I am building my portfolio for GitHub and this struck me so I am sharing it with you!
# This project uses mainly <Matplotlib> 
# Nice having you as a fellow learner and friendly competitor !
# Wish you and your family and loved ones a Merry Christmas and Happy New Year !!!
# ---------------------------------------------------------------------------------------------
# Also like to share with you this Youtube music: https://www.youtube.com/watch?v=IXc2yLBYET0
# ---------------------------------------------------------------------------------------------

import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle
from matplotlib.patches import FancyBboxPatch, PathPatch
from matplotlib.path import Path
import numpy as np


# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add the tree ornaments (
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9),
    (4.6, 2.4), (5.4, 2.4), (4.7, 2.1), (5.3, 2.1),
    (4.9, 1.9), (5.1, 1.9), (4.75, 2.0), (5.25, 2.0)
]
colors = ['red', 'gold', 'lightblue']  # Set ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))  # Larger ornaments

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")


# Add festive text 
ax.text(5, 5.5, "Merry Christmas", color="#FFD700", fontsize=26, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')


# Add evenly spread decorative star-shaped snowflakes
# The snowflakes are randomized at different locations everytime u PLAY the jupyter notebook
for _ in range(70):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)


# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))


# Add snow pile at the bottom
snow_x = np.linspace(0, 10, 50)
snow_y = np.sin(snow_x) * 0.2 + 0.3
ax.fill_between(snow_x, 0, snow_y, color='white', zorder=2)


# I deliberately add a Blue Penguin (as close as possible to the plushy u showed during class activity) 
# To make this project customized for you !!

# Add Xinni's plush penguin Body 
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly

# Add Xinni's plush penguin's Eyes 
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Add Xinni's plush penguin's Beak 
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Add Xinni's plush penguin's Feet 
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right foot

# Define the penguin's bubble body
bubble = FancyBboxPatch((7.8, 2.2), 1.8, 0.8, boxstyle="round,pad=0.2", color="white", zorder=12)

# Define the tail of the bubble
tail_vertices = [
    (7.8, 2.4),  # Start of the tail at the bubble
    (7.5, 2.0),  # Point near penguin's beak
    (7.8, 2.2)   # End of the tail at the bubble
]
tail_codes = [Path.MOVETO, Path.LINETO, Path.LINETO]
tail_path = Path(tail_vertices, tail_codes)
tail = PathPatch(tail_path, color="white", zorder=12)

# Add the bubble and tail to the canvas
ax.add_patch(bubble)
ax.add_patch(tail)

# Add text inside the bubble
ax.text(8.7, 2.6, "Xinni   \n Hwaiting !!!", color="black", fontsize=15, ha='center', va='center', fontweight='bold',zorder=13)

# Display the card
plt.show()

# %%
# I am building my portfolio for GitHub and this struck me so I am sharing it with you!
# This project uses mainly <Matplotlib> 
# RE- PLAY the notebook each time to get random effect
# Thank you and Nice having you as a fellow learner and friendly competitor !
# Wish you and your family and loved ones a Merry Christmas and Happy New Year !!!
# ---------------------------------------------------------------------------------------------
# The accompanying music is at : https://www.youtube.com/watch?v=IXc2yLBYET0
# ---------------------------------------------------------------------------------------------

import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Wedge, Rectangle
from matplotlib.patches import FancyBboxPatch, PathPatch
from matplotlib.path import Path
import numpy as np


# Set up the canvas
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 10)
ax.set_ylim(0, 6)
ax.axis('off')  # Remove axes for a cleaner look

# Change the background to navy blue
fig.patch.set_facecolor('navy')
ax.set_facecolor('navy')

# Add a Christmas tree
tree_base_x = [4.5, 5, 5.5]
tree_base_y = [1.5, 4.5, 1.5]
ax.fill(tree_base_x, tree_base_y, color="green")

# Add a trunk to the tree
ax.add_patch(Rectangle((4.8, 1), 0.4, 0.5, color="saddlebrown"))

# Add the tree ornaments (
ornament_positions = [
    (4.75, 3.2), (5.25, 3.8), (4.9, 2.6), (5.1, 3.4),
    (4.6, 3.5), (5.4, 4.0), (4.7, 2.8), (5.3, 3.2),
    (5.0, 3.9), (4.8, 3.7), (5.2, 3.1), (4.95, 2.9),
    (4.6, 2.4), (5.4, 2.4), (4.7, 2.1), (5.3, 2.1),
    (4.9, 1.9), (5.1, 1.9), (4.75, 2.0), (5.25, 2.0)
]
colors = ['red', 'gold', 'lightblue']  # Set ornament colors
for (ox, oy) in ornament_positions:
    ax.add_patch(Ellipse((ox, oy), 0.2, 0.2, color=np.random.choice(colors), zorder=10))  # Larger ornaments

# Add the star on top of the tree
ax.scatter(5, 4.5, color="gold", s=200, marker="*")


# Add festive text 
ax.text(5, 5.5, "Merry Christmas", color="#FFD700", fontsize=26, ha='center', fontweight='bold')
ax.text(5, 5.1, "and", color="#FFD700", fontsize=20, ha='center')
ax.text(5, 4.7, "Happy New Year 2025!", color="#FFD700", fontsize=26, ha='center', fontweight='bold')


# Add evenly spread decorative star-shaped snowflakes
# The snowflakes are randomized at different locations everytime u RE-PLAY the jupyter notebook
for _ in range(120):
    while True:
        x_snow = np.random.uniform(0, 10)  # Uniformly distributed x-coordinates
        y_snow = np.random.uniform(0, 6)   # Uniformly distributed y-coordinates

        # Exclude the text region (center top area: x=4 to 6, y=4.5 to 6)
        if not (4 <= x_snow <= 6 and 4.5 <= y_snow <= 6):
            break

    ax.scatter(x_snow, y_snow, color="white", s=np.random.uniform(50, 100), marker="*", alpha=0.8)


# Add presents under the tree
present_positions = [(4.3, 0.5, 0.6, 0.6), (5.1, 0.5, 0.8, 0.5), (4.7, 0.2, 0.4, 0.4)]
present_colors = ['red', 'purple', 'gold']

for (px, py, pw, ph), color in zip(present_positions, present_colors):
    ax.add_patch(Rectangle((px, py), pw, ph, color=color, zorder=5))
    ax.add_patch(Rectangle((px + pw / 4, py), pw / 8, ph, color="white", zorder=6))
    ax.add_patch(Rectangle((px, py + ph / 2), pw, ph / 8, color="white", zorder=6))


# Add snow pile at the bottom
snow_x = np.linspace(0, 10, 50)
snow_y = np.sin(snow_x) * 0.2 + 0.3
ax.fill_between(snow_x, 0, snow_y, color='white', zorder=5)


# I deliberately add a Blue Penguin (as close as possible to the plushy u showed during class activity) 
# To make this project customized to you !!

# Add Xinni's plush penguin Body 
ax.add_patch(Ellipse((7.0, 1.4), 1.5, 1.2, color='deepskyblue', zorder=8))  # Blue body
ax.add_patch(Ellipse((7.0, 1.4), 1.2, 0.9, color='white', zorder=9))  # White belly

# Add Xinni's plush penguin's Eyes 
ax.add_patch(Wedge((6.7, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Left crescent eye
ax.add_patch(Wedge((7.3, 1.6), 0.15, 0, 180, width=0.03, color='black', zorder=10))  # Right crescent eye

# Add Xinni's plush penguin's Beak 
ax.add_patch(Ellipse((7.0, 1.5), 0.15, 0.08, color='gold', zorder=11))  # Small yellow beak

# Add Xinni's plush penguin's Feet 
ax.add_patch(Ellipse((6.8, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Left foot
ax.add_patch(Ellipse((7.2, 1.1), 0.3, 0.15, color='gold', zorder=10))  # Right foot

# Define the penguin's bubble body
bubble = FancyBboxPatch((7.8, 2.2), 1.8, 0.8, boxstyle="round,pad=0.2", color="white", zorder=12)

# Define the tail of the bubble
tail_vertices = [
    (7.8, 2.4),  # Start of the tail at the bubble
    (7.5, 2.0),  # Point near penguin's beak
    (7.8, 2.2)   # End of the tail at the bubble
]
tail_codes = [Path.MOVETO, Path.LINETO, Path.LINETO]
tail_path = Path(tail_vertices, tail_codes)
tail = PathPatch(tail_path, color="white", zorder=12)

# Add the bubble and tail to the canvas
ax.add_patch(bubble)
ax.add_patch(tail)

# Add text inside the bubble
ax.text(8.7, 2.6, "Xinni  \n Hwaiting !!!", color="black", fontsize=15, ha='center', va='center', fontweight='bold',zorder=13)

# Add snowman 
# Snowman body
ax.add_patch(Ellipse((2.5, 1.2), 1.0, 1.0, color='white', zorder=8))  # Bottom ball
ax.add_patch(Ellipse((2.5, 2.0), 0.6, 0.6, color='white', zorder=8))  # Head

# Snowman face
ax.add_patch(Ellipse((2.4, 2.1), 0.05, 0.05, color='black', zorder=9))  # Left eye
ax.add_patch(Ellipse((2.6, 2.1), 0.05, 0.05, color='black', zorder=9))  # Right eye
ax.add_patch(Wedge((2.5, 2.05), 0.1, 0, 180, color='orange', zorder=9))  # Carrot nose

# Snowman buttons
ax.add_patch(Ellipse((2.5, 1.6), 0.05, 0.05, color='black', zorder=9))  # Top button
ax.add_patch(Ellipse((2.5, 1.3), 0.05, 0.05, color='black', zorder=9))  # Bottom button

# Snowman hat
ax.add_patch(Rectangle((2.4, 2.3), 0.2, 0.1, color='black', zorder=10))  # Hat top
ax.add_patch(Rectangle((2.35, 2.25), 0.3, 0.03, color='black', zorder=10))  # Hat brim

# Snowman scarf
ax.add_patch(Rectangle((2.4, 1.9), 0.2, 0.03, color='red', zorder=9))  # Horizontal part
ax.add_patch(Rectangle((2.48, 1.75), 0.03, 0.15, color='red', zorder=9))  # Vertical part

# Snowman arms
ax.plot([2.2, 1.9], [1.5, 1.7], color="saddlebrown", linewidth=2, zorder=8)  # Left arm
ax.plot([2.8, 3.1], [1.5, 1.7], color="saddlebrown", linewidth=2, zorder=8)  # Right arm

# Display the card
plt.show()
